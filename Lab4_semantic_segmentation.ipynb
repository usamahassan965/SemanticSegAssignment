# %% [markdown]
# # Semantic Image Segmentation

# %% [markdown]
# Semantic segmentation is a computer vision technique that involves dividing an image into meaningful and coherent segments or regions based on their semantic properties such as object, background, and foreground. Unlike simple image segmentation techniques that group pixels based on their color, texture, or intensity, semantic segmentation goes further by associating each segment with a semantic label that represents the class or category of the object that it belongs to.
#
# The objective of semantic segmentation is to create a precise pixel-level map of the image that assigns a unique label to each pixel based on its semantic content. This technique has many applications in computer vision, including object recognition, scene understanding, and autonomous navigation.
#
# To achieve semantic segmentation, deep learning models like Fully Convolutional Neural Networks (FCN), U-Net, and SegNet have been developed. These models use a combination of convolutional neural networks (CNN) and upsampling techniques to produce a pixel-level segmentation of an input image. The training of these models involves feeding a large dataset of annotated images into the network, which learns to extract features and make semantic predictions.
#
# Overall, semantic segmentation is a powerful tool in computer vision that enables machines to interpret images at a higher level of abstraction, allowing for more advanced applications in fields like self-driving cars, robotics, and medical imaging.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms as T
import torchvision
import torch.nn.functional as F
from torch.autograd import Variable

from PIL import Image
import cv2
import albumentations as A

import time
import os
from tqdm.notebook import tqdm
# !pip install -q torchsummary

from torchsummary import summary

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Cars Segmentation Dataset
#
# This is a sample semantic image segmentation dataset. It contains images of cars and their segmentation masks. Most of the images were taken from side of the car. Image and its corresponding mask have the same name. For example, 003.png in the "masks" folder corresponds to the 003.png file in the "images" folder. Each pixel in a mask shows the class of the corresponding pixel in the corresponding image. For example, if value of pixel (3, 7) is 1, it means pixel (3,7) in the corresponding image belongs to class 1. We have following 5 classes in this dataset:
#
# - 0 - background
# - 1 - car
# - 2 - wheel
# - 3 - light
# - 4 - windows
#
# https://www.kaggle.com/datasets/intelecai/car-segmentation

# %%
# !gdown https://drive.google.com/file/d/1BUylbm5aD82v7Q-R6L-tEEX39SnWqRj3/view?usp=sharing --fuzzy
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1BUylbm5aD82v7Q-R6L-tEEX39SnWqRj3
# To: /content/car-segmentation.zip
# 100% 463M/463M [00:13<00:00, 35.0MB/s]

# %%
# !unzip /content/car-segmentation.zip
# Out:
# Archive:  /content/car-segmentation.zip
#  extracting: car-segmentation/classes.txt
#    creating: car-segmentation/images/
#   inflating: car-segmentation/images/003.png
#   inflating: car-segmentation/images/105618339-super-purple-modern-suv-car-side-view.png
#   inflating: car-segmentation/images/105618639-modern-pale-blue-suv-car-side-view.png
#   inflating: car-segmentation/images/156551_preview.png
#   inflating: car-segmentation/images/178583_Side_Profile_Web.png
#   inflating: car-segmentation/images/1965-Shelby-Cobra-Roadster-Side-Profile.png
#   inflating: car-segmentation/images/2008-Morgan-Life-Car-Side-Speed-1024x768.png
#   inflating: car-segmentation/images/2009-Ford-Kuga-Show-Car-Side-1280x960.png
#   inflating: car-segmentation/images/2011-278656-pagani-huayra-side-view1.png
#   inflating: car-segmentation/images/2015_aston_martin_db10_4.png
#   inflating: car-segmentation/images/2018-bm4-gt4-sports-car-side-view-pk.png
#   inflating: car-segmentation/images/2018-nissan-sentra-2017-nissan-sentra-car-nissan-micra-png-f.png
#   inflating: car-segmentation/images/2019-acura-rdx-11.png
#   inflating: car-segmentation/images/2019-ferrari-488-spider-side-view-carbuzz-669506.png
#   inflating: car-segmentation/images/2020-Honda-City-7-1068x672.png
#   inflating: car-segmentation/images/202-2028012_car-png-hd-side-view-transparent-png.png
#   inflating: car-segmentation/images/39839516-black-sedan-car-side-view.png
#   inflating: car-segmentation/images/3d_metal_machine_160_2000x.png
#   inflating: car-segmentation/images/45303-Kit-stickers-bandes-Mitsubishi-L200.png
#   inflating: car-segmentation/images/47865-Kit-Bandes-Bas-Caisse-Porsche-Boxster.png
#   inflating: car-segmentation/images/62271369-ehrf%C3%BCrchtig-gelb-muscle-car-seitenansicht.png
#   inflating: car-segmentation/images/63-633585_infiniti-png-car-side-profile-png-transparent-png.png
#   inflating: car-segmentation/images/676069.png
#   inflating: car-segmentation/images/75538664-compact-suv-car-side-view.png
#   inflating: car-segmentation/images/75-752748_red-jaguar-f-type-car-side-view-png.png
#   inflating: car-segmentation/images/865-8651925_fiat-tipo-company-car-side-view.png
#   inflating: car-segmentation/images/8b21a8c96a9d38143f7b29c0f8e4fe3d.png
#   inflating: car-segmentation/images/94374978-pretty-pink-modern-fast-city-car-side-view.png
#   inflating: car-segmentation/images/a594e4d7b37f6e9357ca3b92a4125262.png
#   inflating: car-segmentation/images/anne-nygard-6t7wZAU3nuY-unsplash.png
#   inflating: car-segmentation/images/Aston-Marton-Car-Branding-Right-Side-PSD-Mockup.png
#   inflating: car-segmentation/images/audir8.png
#   inflating: car-segmentation/images/audi-r8-v10-car-side-view.png
#   inflating: car-segmentation/images/auto-machine-grey-toyota-car-hd-wallpaper-preview.png
#   inflating: car-segmentation/images/bb29a1ee64eaa0186407c5d2ead9c959.png
#   inflating: car-segmentation/images/black_side_shot_GALLERY.png
#   inflating: car-segmentation/images/black-volkswagen-golf.png
#   inflating: car-segmentation/images/brandon-paul-ErH1LWnAKXg-unsplash.png
#   inflating: car-segmentation/images/Car.png
#   inflating: car-segmentation/images/car1112.png
#   inflating: car-segmentation/images/car-graphic-19.png
#   inflating: car-segmentation/images/car-side.png
#   inflating: car-segmentation/images/carsticker.png
#   inflating: car-segmentation/images/d9ce7968a4073918ce554523363caa73.png
#   inflating: car-segmentation/images/depositphotos_176490672-stock-photo-white-toyota-suv-car-sid.png
#   inflating: car-segmentation/images/dimon-blr-rwgyRguL_YE-unsplash.png
#   inflating: car-segmentation/images/driver-clipart-horsepower-sports-car-side-view-png-transparent-side-car-png-880_295.png
#   inflating: car-segmentation/images/e4a49bfe830012333d89a9861f6c4821.png
#   inflating: car-segmentation/images/G40-Junior-GT5-car-side.png
#   inflating: car-segmentation/images/gabor-papp-k688MQzA3LI-unsplash.png
#   inflating: car-segmentation/images/Haa04c90142df4a01829fd6d84b7b3347H.png
#   inflating: car-segmentation/images/Hba200d821f7b485cb1975db750260e88o.png
#   inflating: car-segmentation/images/hd-car-side-view-transparent-background-transparent-png-image-car-side-png-1947_776.png
#   inflating: car-segmentation/images/il_570xN-1259936156_o9i9.png
#   inflating: car-segmentation/images/im10.png
#   inflating: car-segmentation/images/im11.png
#   inflating: car-segmentation/images/im12.png
#   inflating: car-segmentation/images/im13.png
#   inflating: car-segmentation/images/im14.png
#   inflating: car-segmentation/images/im15.png
#   inflating: car-segmentation/images/im16.png
#   inflating: car-segmentation/images/im18.png
#   inflating: car-segmentation/images/im19.png
#   inflating: car-segmentation/images/im2.png
#   inflating: car-segmentation/images/im20.png
#   inflating: car-segmentation/images/im21.png
#   inflating: car-segmentation/images/im22.png
#   inflating: car-segmentation/images/im23.png
#   inflating: car-segmentation/images/im24.png
#   inflating: car-segmentation/images/im25.png
#   inflating: car-segmentation/images/im3.png
#   inflating: car-segmentation/images/im4.png
#   inflating: car-segmentation/images/im5.png
#   inflating: car-segmentation/images/im6.png
#   inflating: car-segmentation/images/im7.png
#   inflating: car-segmentation/images/im8.png
#   inflating: car-segmentation/images/im9.png
#   inflating: car-segmentation/images/image%20(10).png
#   inflating: car-segmentation/images/image%20(11).png
#   inflating: car-segmentation/images/image%20(12).png
#   inflating: car-segmentation/images/image%20(13).png
#   inflating: car-segmentation/images/image%20(14).png
#   inflating: car-segmentation/images/image%20(15).png
#   inflating: car-segmentation/images/image%20(16).png
#   inflating: car-segmentation/images/IMG_20201123_131711.png
#   inflating: car-segmentation/images/IMG_20201123_132159.png
#   inflating: car-segmentation/images/IMG_20201123_132218__01.png
#   inflating: car-segmentation/images/IMG_20201123_132237.png
#   inflating: car-segmentation/images/IMG_20201123_132248.png
#   inflating: car-segmentation/images/IMG_20201123_132316__01.png
#   inflating: car-segmentation/images/IMG_20201123_132345__01.png
#   inflating: car-segmentation/images/IMG_20201123_132401__01.png
#   inflating: car-segmentation/images/IMG_20201123_132516__01.png
#   inflating: car-segmentation/images/IMG_20201123_132539.png
#   inflating: car-segmentation/images/IMG_20201123_132604__01.png
#   inflating: car-segmentation/images/IMG_20201123_132617.png
#   inflating: car-segmentation/images/IMG_20201123_132631.png
#   inflating: car-segmentation/images/IMG_20201123_132708.png
#   inflating: car-segmentation/images/IMG_20201123_132724.png
#   inflating: car-segmentation/images/IMG_20201123_132752.png
#   inflating: car-segmentation/images/IMG_20201123_132800__01.png
#   inflating: car-segmentation/images/IMG_20201123_132905.png
#   inflating: car-segmentation/images/IMG_20201123_132929__01.png
#   inflating: car-segmentation/images/IMG_20201123_133022__01.png
#   inflating: car-segmentation/images/IMG_20201123_133046.png
#   inflating: car-segmentation/images/IMG_20201123_133302.png
#   inflating: car-segmentation/images/IMG_20201123_133402.png
#   inflating: car-segmentation/images/IMG_20201123_133422.png
#   inflating: car-segmentation/images/IMG_20201123_133510__01.png
#   inflating: car-segmentation/images/IMG_20201123_134711.png
#   inflating: car-segmentation/images/IMG_20201123_134940.png
#   inflating: car-segmentation/images/IMG_20201123_134949.png
#   inflating: car-segmentation/images/IMG_20201123_135003.png
#   inflating: car-segmentation/images/IMG_20201123_135102.png
#   inflating: car-segmentation/images/IMG_20201123_135112.png
#   inflating: car-segmentation/images/IMG_20201123_135123.png
#   inflating: car-segmentation/images/IMG_20201123_135137.png
#   inflating: car-segmentation/images/IMG_20201123_135204.png
#   inflating: car-segmentation/images/IMG_20201123_135540.png
#   inflating: car-segmentation/images/IMG_20201123_135616.png
#   inflating: car-segmentation/images/IMG_20201123_135641.png
#   inflating: car-segmentation/images/IMG_20201123_135703.png
#   inflating: car-segmentation/images/IMG_20201123_135713.png
#   inflating: car-segmentation/images/IMG_20201123_135740.png
#   inflating: car-segmentation/images/IMG_20201123_135806.png
#   inflating: car-segmentation/images/IMG_20201123_135900.png
#   inflating: car-segmentation/images/IMG_20201123_135908.png
#   inflating: car-segmentation/images/IMG_20201123_140214.png
#   inflating: car-segmentation/images/IMG_20201123_140245.png
#   inflating: car-segmentation/images/IMG_20201123_141046.png
#   inflating: car-segmentation/images/IMG_20201123_141057.png
#   inflating: car-segmentation/images/IMG_20201123_141123.png
#   inflating: car-segmentation/images/IMG_20201123_142755.png
#   inflating: car-segmentation/images/IMG_20201123_142834__01.png
#   inflating: car-segmentation/images/IMG_20201123_142855__01.png
#   inflating: car-segmentation/images/IMG_20201123_142906.png
#   inflating: car-segmentation/images/IMG_20201123_142920__01.png
#   inflating: car-segmentation/images/IMG_20201123_142931.png
#   inflating: car-segmentation/images/IMG_20201123_142937.png
#   inflating: car-segmentation/images/IMG_20201123_142949__01.png
#   inflating: car-segmentation/images/IMG_20201123_142958__01.png
#   inflating: car-segmentation/images/IMG_20201123_143012.png
#   inflating: car-segmentation/images/IMG_20201123_143036.png
#   inflating: car-segmentation/images/IMG_20201123_143055.png
#   inflating: car-segmentation/images/IMG_20201123_143103.png
#   inflating: car-segmentation/images/IMG_20201123_143129__01.png
#   inflating: car-segmentation/images/IMG_20201123_143144__01.png
#   inflating: car-segmentation/images/IMG_20201123_143155.png
#   inflating: car-segmentation/images/IMG_20201123_143206.png
#   inflating: car-segmentation/images/IMG_20201123_143217__01.png
#   inflating: car-segmentation/images/IMG_20201123_143227.png
#   inflating: car-segmentation/images/IMG_20201123_143236.png
#   inflating: car-segmentation/images/IMG_20201123_143245.png
#   inflating: car-segmentation/images/IMG_20201123_143336.png
#   inflating: car-segmentation/images/IMG_20201123_143344.png
#   inflating: car-segmentation/images/IMG_20201123_143405.png
#   inflating: car-segmentation/images/IMG_20201123_143412.png
#   inflating: car-segmentation/images/IMG_20201123_143426.png
#   inflating: car-segmentation/images/IMG_20201123_143435.png
#   inflating: car-segmentation/images/IMG_20201123_143506.png
#   inflating: car-segmentation/images/IMG_20201123_143523.png
#   inflating: car-segmentation/images/IMG_20201123_143532.png
#   inflating: car-segmentation/images/IMG_20201123_143545__01.png
#   inflating: car-segmentation/images/IMG_20201123_143605.png
#   inflating: car-segmentation/images/IMG_20201123_143617.png
#   inflating: car-segmentation/images/IMG_20201123_143628.png
#   inflating: car-segmentation/images/IMG_20201123_143657.png
#   inflating: car-segmentation/images/IMG_20201123_143710.png
#   inflating: car-segmentation/images/IMG_20201123_143723.png
#   inflating: car-segmentation/images/IMG_20201123_143739.png
#   inflating: car-segmentation/images/IMG_20201123_143749__01.png
#   inflating: car-segmentation/images/IMG_20201123_143758.png
#   inflating: car-segmentation/images/IMG_20201123_143813.png
#   inflating: car-segmentation/images/IMG_20201123_143830.png
#   inflating: car-segmentation/images/IMG_20201123_143839__01.png
#   inflating: car-segmentation/images/IMG_20201123_143849.png
#   inflating: car-segmentation/images/IMG_20201123_143858__01.png
#   inflating: car-segmentation/images/IMG_20201123_143908.png
#   inflating: car-segmentation/images/IMG_20201123_143925.png
#   inflating: car-segmentation/images/IMG_20201123_143935.png
#   inflating: car-segmentation/images/IMG_20201123_143945.png
#   inflating: car-segmentation/images/IMG_20201123_143954.png
#   inflating: car-segmentation/images/IMG_20201123_144018__01.png
#   inflating: car-segmentation/images/IMG_20201123_144114.png
#   inflating: car-segmentation/images/IMG_20201123_144130.png
#   inflating: car-segmentation/images/IMG_20201123_144418.png
#   inflating: car-segmentation/images/IMG_20201123_144532.png
#   inflating: car-segmentation/images/IMG_20201123_144550.png
#   inflating: car-segmentation/images/IMG_20201123_144606.png
#   inflating: car-segmentation/images/IMG_20201123_144621.png
#   inflating: car-segmentation/images/IMG_20201123_144636.png
#   inflating: car-segmentation/images/IMG_20201123_144700.png
#   inflating: car-segmentation/images/IMG_20201123_144709.png
#   inflating: car-segmentation/images/IMG_20201123_144726.png
#   inflating: car-segmentation/images/IMG_20201123_144740.png
#   inflating: car-segmentation/images/IMG_20201123_144750.png
#   inflating: car-segmentation/images/IMG_20201123_144800.png
#   inflating: car-segmentation/images/Jeep-Wrangler-Left-Side-View-79407.png
#   inflating: car-segmentation/images/kevin-bhagat-3cLpiv8h5so-unsplash.png
#   inflating: car-segmentation/images/m_next_037.png
#   inflating: car-segmentation/images/malusi-msomi-1Jz3Xq7EcrI-unsplash.png
#   inflating: car-segmentation/images/Maruti-Suzuki-Ertiga-Right-Side-111110.png
#   inflating: car-segmentation/images/maxresdefault.png
#   inflating: car-segmentation/images/Monster_energy_custom.png
#   inflating: car-segmentation/images/Police-Car-side-view.png
#   inflating: car-segmentation/images/Safety_Car_side_2015_Malaysia.png
#   inflating: car-segmentation/images/side-view-(left)-90.png
#   inflating: car-segmentation/images/toyota-gt86-blue-sport-car-side-view-wallpaper-preview.png
#   inflating: car-segmentation/images/unnamed.png
#   inflating: car-segmentation/images/Volkswagen-Golf_GTI_5-door-2004-1600-10.png
#   inflating: car-segmentation/images/yuvraj-singh-keRubFoQix8-unsplash.png
#   inflating: car-segmentation/masks.json
#    creating: car-segmentation/masks/
#   inflating: car-segmentation/masks/003.png
#   inflating: car-segmentation/masks/105618339-super-purple-modern-suv-car-side-view.png
#   inflating: car-segmentation/masks/105618639-modern-pale-blue-suv-car-side-view.png
#   inflating: car-segmentation/masks/156551_preview.png
#   inflating: car-segmentation/masks/178583_Side_Profile_Web.png
#   inflating: car-segmentation/masks/1965-Shelby-Cobra-Roadster-Side-Profile.png
#   inflating: car-segmentation/masks/2008-Morgan-Life-Car-Side-Speed-1024x768.png
#   inflating: car-segmentation/masks/2009-Ford-Kuga-Show-Car-Side-1280x960.png
#   inflating: car-segmentation/masks/2011-278656-pagani-huayra-side-view1.png
#   inflating: car-segmentation/masks/2015_aston_martin_db10_4.png
#   inflating: car-segmentation/masks/2018-bm4-gt4-sports-car-side-view-pk.png
#   inflating: car-segmentation/masks/2018-nissan-sentra-2017-nissan-sentra-car-nissan-micra-png-f.png
#   inflating: car-segmentation/masks/2019-acura-rdx-11.png
#   inflating: car-segmentation/masks/2019-ferrari-488-spider-side-view-carbuzz-669506.png
#   inflating: car-segmentation/masks/2020-Honda-City-7-1068x672.png
#   inflating: car-segmentation/masks/202-2028012_car-png-hd-side-view-transparent-png.png
#   inflating: car-segmentation/masks/39839516-black-sedan-car-side-view.png
#   inflating: car-segmentation/masks/3d_metal_machine_160_2000x.png
#   inflating: car-segmentation/masks/45303-Kit-stickers-bandes-Mitsubishi-L200.png
#   inflating: car-segmentation/masks/47865-Kit-Bandes-Bas-Caisse-Porsche-Boxster.png
#   inflating: car-segmentation/masks/62271369-ehrf%C3%BCrchtig-gelb-muscle-car-seitenansicht.png
#   inflating: car-segmentation/masks/63-633585_infiniti-png-car-side-profile-png-transparent-png.png
#   inflating: car-segmentation/masks/676069.png
#   inflating: car-segmentation/masks/75538664-compact-suv-car-side-view.png
#   inflating: car-segmentation/masks/75-752748_red-jaguar-f-type-car-side-view-png.png
#   inflating: car-segmentation/masks/865-8651925_fiat-tipo-company-car-side-view.png
#   inflating: car-segmentation/masks/8b21a8c96a9d38143f7b29c0f8e4fe3d.png
#   inflating: car-segmentation/masks/94374978-pretty-pink-modern-fast-city-car-side-view.png
#   inflating: car-segmentation/masks/a594e4d7b37f6e9357ca3b92a4125262.png
#   inflating: car-segmentation/masks/anne-nygard-6t7wZAU3nuY-unsplash.png
#   inflating: car-segmentation/masks/Aston-Marton-Car-Branding-Right-Side-PSD-Mockup.png
#   inflating: car-segmentation/masks/audir8.png
#   inflating: car-segmentation/masks/audi-r8-v10-car-side-view.png
#   inflating: car-segmentation/masks/auto-machine-grey-toyota-car-hd-wallpaper-preview.png
#   inflating: car-segmentation/masks/bb29a1ee64eaa0186407c5d2ead9c959.png
#   inflating: car-segmentation/masks/black_side_shot_GALLERY.png
#   inflating: car-segmentation/masks/black-volkswagen-golf.png
#   inflating: car-segmentation/masks/brandon-paul-ErH1LWnAKXg-unsplash.png
#  extracting: car-segmentation/masks/Car.png
#   inflating: car-segmentation/masks/car1112.png
#   inflating: car-segmentation/masks/car-graphic-19.png
#   inflating: car-segmentation/masks/car-side.png
#   inflating: car-segmentation/masks/carsticker.png
#  extracting: car-segmentation/masks/d9ce7968a4073918ce554523363caa73.png
#   inflating: car-segmentation/masks/depositphotos_176490672-stock-photo-white-toyota-suv-car-sid.png
#   inflating: car-segmentation/masks/dimon-blr-rwgyRguL_YE-unsplash.png
#   inflating: car-segmentation/masks/driver-clipart-horsepower-sports-car-side-view-png-transparent-side-car-png-880_295.png
#   inflating: car-segmentation/masks/e4a49bfe830012333d89a9861f6c4821.png
#   inflating: car-segmentation/masks/G40-Junior-GT5-car-side.png
#   inflating: car-segmentation/masks/gabor-papp-k688MQzA3LI-unsplash.png
#   inflating: car-segmentation/masks/Haa04c90142df4a01829fd6d84b7b3347H.png
#   inflating: car-segmentation/masks/Hba200d821f7b485cb1975db750260e88o.png
#   inflating: car-segmentation/masks/hd-car-side-view-transparent-background-transparent-png-image-car-side-png-1947_776.png
#   inflating: car-segmentation/masks/il_570xN-1259936156_o9i9.png
#   inflating: car-segmentation/masks/im10.png
#   inflating: car-segmentation/masks/im11.png
#   inflating: car-segmentation/masks/im12.png
#   inflating: car-segmentation/masks/im13.png
#   inflating: car-segmentation/masks/im14.png
#   inflating: car-segmentation/masks/im15.png
#   inflating: car-segmentation/masks/im16.png
#   inflating: car-segmentation/masks/im18.png
#   inflating: car-segmentation/masks/im19.png
#   inflating: car-segmentation/masks/im2.png
#   inflating: car-segmentation/masks/im20.png
#   inflating: car-segmentation/masks/im21.png
#   inflating: car-segmentation/masks/im22.png
#   inflating: car-segmentation/masks/im23.png
#   inflating: car-segmentation/masks/im24.png
#   inflating: car-segmentation/masks/im25.png
#   inflating: car-segmentation/masks/im3.png
#   inflating: car-segmentation/masks/im4.png
#   inflating: car-segmentation/masks/im5.png
#   inflating: car-segmentation/masks/im6.png
#   inflating: car-segmentation/masks/im7.png
#   inflating: car-segmentation/masks/im8.png
#  extracting: car-segmentation/masks/im9.png
#  extracting: car-segmentation/masks/image%20(10).png
#  extracting: car-segmentation/masks/image%20(11).png
#  extracting: car-segmentation/masks/image%20(12).png
#   inflating: car-segmentation/masks/image%20(13).png
#  extracting: car-segmentation/masks/image%20(14).png
#  extracting: car-segmentation/masks/image%20(15).png
#  extracting: car-segmentation/masks/image%20(16).png
#   inflating: car-segmentation/masks/IMG_20201123_131711.png
#   inflating: car-segmentation/masks/IMG_20201123_132159.png
#   inflating: car-segmentation/masks/IMG_20201123_132218__01.png
#   inflating: car-segmentation/masks/IMG_20201123_132237.png
#   inflating: car-segmentation/masks/IMG_20201123_132248.png
#   inflating: car-segmentation/masks/IMG_20201123_132316__01.png
#   inflating: car-segmentation/masks/IMG_20201123_132345__01.png
#   inflating: car-segmentation/masks/IMG_20201123_132401__01.png
#   inflating: car-segmentation/masks/IMG_20201123_132516__01.png
#   inflating: car-segmentation/masks/IMG_20201123_132539.png
#   inflating: car-segmentation/masks/IMG_20201123_132604__01.png
#   inflating: car-segmentation/masks/IMG_20201123_132617.png
#   inflating: car-segmentation/masks/IMG_20201123_132631.png
#   inflating: car-segmentation/masks/IMG_20201123_132708.png
#   inflating: car-segmentation/masks/IMG_20201123_132724.png
#   inflating: car-segmentation/masks/IMG_20201123_132752.png
#   inflating: car-segmentation/masks/IMG_20201123_132800__01.png
#   inflating: car-segmentation/masks/IMG_20201123_132905.png
#   inflating: car-segmentation/masks/IMG_20201123_132929__01.png
#   inflating: car-segmentation/masks/IMG_20201123_133022__01.png
#   inflating: car-segmentation/masks/IMG_20201123_133046.png
#   inflating: car-segmentation/masks/IMG_20201123_133302.png
#   inflating: car-segmentation/masks/IMG_20201123_133402.png
#   inflating: car-segmentation/masks/IMG_20201123_133422.png
#   inflating: car-segmentation/masks/IMG_20201123_133510__01.png
#   inflating: car-segmentation/masks/IMG_20201123_134711.png
#   inflating: car-segmentation/masks/IMG_20201123_134940.png
#   inflating: car-segmentation/masks/IMG_20201123_134949.png
#   inflating: car-segmentation/masks/IMG_20201123_135003.png
#   inflating: car-segmentation/masks/IMG_20201123_135102.png
#   inflating: car-segmentation/masks/IMG_20201123_135112.png
#   inflating: car-segmentation/masks/IMG_20201123_135123.png
#   inflating: car-segmentation/masks/IMG_20201123_135137.png
#   inflating: car-segmentation/masks/IMG_20201123_135204.png
#   inflating: car-segmentation/masks/IMG_20201123_135540.png
#   inflating: car-segmentation/masks/IMG_20201123_135616.png
#   inflating: car-segmentation/masks/IMG_20201123_135641.png
#   inflating: car-segmentation/masks/IMG_20201123_135703.png
#   inflating: car-segmentation/masks/IMG_20201123_135713.png
#   inflating: car-segmentation/masks/IMG_20201123_135740.png
#   inflating: car-segmentation/masks/IMG_20201123_135806.png
#   inflating: car-segmentation/masks/IMG_20201123_135900.png
#   inflating: car-segmentation/masks/IMG_20201123_135908.png
#   inflating: car-segmentation/masks/IMG_20201123_140214.png
#   inflating: car-segmentation/masks/IMG_20201123_140245.png
#   inflating: car-segmentation/masks/IMG_20201123_141046.png
#   inflating: car-segmentation/masks/IMG_20201123_141057.png
#   inflating: car-segmentation/masks/IMG_20201123_141123.png
#   inflating: car-segmentation/masks/IMG_20201123_142755.png
#   inflating: car-segmentation/masks/IMG_20201123_142834__01.png
#   inflating: car-segmentation/masks/IMG_20201123_142855__01.png
#   inflating: car-segmentation/masks/IMG_20201123_142906.png
#   inflating: car-segmentation/masks/IMG_20201123_142920__01.png
#   inflating: car-segmentation/masks/IMG_20201123_142931.png
#   inflating: car-segmentation/masks/IMG_20201123_142937.png
#   inflating: car-segmentation/masks/IMG_20201123_142949__01.png
#   inflating: car-segmentation/masks/IMG_20201123_142958__01.png
#   inflating: car-segmentation/masks/IMG_20201123_143012.png
#   inflating: car-segmentation/masks/IMG_20201123_143036.png
#   inflating: car-segmentation/masks/IMG_20201123_143055.png
#   inflating: car-segmentation/masks/IMG_20201123_143103.png
#   inflating: car-segmentation/masks/IMG_20201123_143129__01.png
#   inflating: car-segmentation/masks/IMG_20201123_143144__01.png
#   inflating: car-segmentation/masks/IMG_20201123_143155.png
#   inflating: car-segmentation/masks/IMG_20201123_143206.png
#   inflating: car-segmentation/masks/IMG_20201123_143217__01.png
#   inflating: car-segmentation/masks/IMG_20201123_143227.png
#   inflating: car-segmentation/masks/IMG_20201123_143236.png
#   inflating: car-segmentation/masks/IMG_20201123_143245.png
#   inflating: car-segmentation/masks/IMG_20201123_143336.png
#   inflating: car-segmentation/masks/IMG_20201123_143344.png
#   inflating: car-segmentation/masks/IMG_20201123_143405.png
#   inflating: car-segmentation/masks/IMG_20201123_143412.png
#   inflating: car-segmentation/masks/IMG_20201123_143426.png
#   inflating: car-segmentation/masks/IMG_20201123_143435.png
#   inflating: car-segmentation/masks/IMG_20201123_143506.png
#   inflating: car-segmentation/masks/IMG_20201123_143523.png
#   inflating: car-segmentation/masks/IMG_20201123_143532.png
#   inflating: car-segmentation/masks/IMG_20201123_143545__01.png
#   inflating: car-segmentation/masks/IMG_20201123_143605.png
#   inflating: car-segmentation/masks/IMG_20201123_143617.png
#   inflating: car-segmentation/masks/IMG_20201123_143628.png
#   inflating: car-segmentation/masks/IMG_20201123_143657.png
#   inflating: car-segmentation/masks/IMG_20201123_143710.png
#   inflating: car-segmentation/masks/IMG_20201123_143723.png
#   inflating: car-segmentation/masks/IMG_20201123_143739.png
#   inflating: car-segmentation/masks/IMG_20201123_143749__01.png
#   inflating: car-segmentation/masks/IMG_20201123_143758.png
#   inflating: car-segmentation/masks/IMG_20201123_143813.png
#   inflating: car-segmentation/masks/IMG_20201123_143830.png
#   inflating: car-segmentation/masks/IMG_20201123_143839__01.png
#   inflating: car-segmentation/masks/IMG_20201123_143849.png
#   inflating: car-segmentation/masks/IMG_20201123_143858__01.png
#   inflating: car-segmentation/masks/IMG_20201123_143908.png
#   inflating: car-segmentation/masks/IMG_20201123_143925.png
#   inflating: car-segmentation/masks/IMG_20201123_143935.png
#   inflating: car-segmentation/masks/IMG_20201123_143945.png
#   inflating: car-segmentation/masks/IMG_20201123_143954.png
#   inflating: car-segmentation/masks/IMG_20201123_144018__01.png
#   inflating: car-segmentation/masks/IMG_20201123_144114.png
#   inflating: car-segmentation/masks/IMG_20201123_144130.png
#   inflating: car-segmentation/masks/IMG_20201123_144418.png
#   inflating: car-segmentation/masks/IMG_20201123_144532.png
#   inflating: car-segmentation/masks/IMG_20201123_144550.png
#   inflating: car-segmentation/masks/IMG_20201123_144606.png
#   inflating: car-segmentation/masks/IMG_20201123_144621.png
#   inflating: car-segmentation/masks/IMG_20201123_144636.png
#   inflating: car-segmentation/masks/IMG_20201123_144700.png
#   inflating: car-segmentation/masks/IMG_20201123_144709.png
#   inflating: car-segmentation/masks/IMG_20201123_144726.png
#   inflating: car-segmentation/masks/IMG_20201123_144740.png
#   inflating: car-segmentation/masks/IMG_20201123_144750.png
#   inflating: car-segmentation/masks/IMG_20201123_144800.png
#   inflating: car-segmentation/masks/Jeep-Wrangler-Left-Side-View-79407.png
#   inflating: car-segmentation/masks/kevin-bhagat-3cLpiv8h5so-unsplash.png
#   inflating: car-segmentation/masks/m_next_037.png
#   inflating: car-segmentation/masks/malusi-msomi-1Jz3Xq7EcrI-unsplash.png
#   inflating: car-segmentation/masks/Maruti-Suzuki-Ertiga-Right-Side-111110.png
#   inflating: car-segmentation/masks/maxresdefault.png
#   inflating: car-segmentation/masks/Monster_energy_custom.png
#   inflating: car-segmentation/masks/Police-Car-side-view.png
#   inflating: car-segmentation/masks/Safety_Car_side_2015_Malaysia.png
#   inflating: car-segmentation/masks/side-view-(left)-90.png
#   inflating: car-segmentation/masks/toyota-gt86-blue-sport-car-side-view-wallpaper-preview.png
#   inflating: car-segmentation/masks/unnamed.png
#   inflating: car-segmentation/masks/Volkswagen-Golf_GTI_5-door-2004-1600-10.png
#   inflating: car-segmentation/masks/yuvraj-singh-keRubFoQix8-unsplash.png

# %%
IMAGE_PATH = "/content/car-segmentation/images/"
MASK_PATH = "/content/car-segmentation/masks/"

# %%
n_classes = 5 
name = []
def create_df():
    #name = []
    for dirname, _, filenames in os.walk(IMAGE_PATH):
        for filename in filenames:
            name.append(filename.split('.')[0])

    return pd.DataFrame({'id': name}, index = np.arange(0, len(name)))

df = create_df()
print('Total Images: ', len(df))
# Out:
# Total Images:  211

# %%
X_trainval, X_test = train_test_split(df['id'].values, test_size=0.1, random_state=19)
X_train, X_val = train_test_split(X_trainval, test_size=0.15, random_state=19)

print('Train Size   : ', len(X_train))
print('Val Size     : ', len(X_val))
print('Test Size    : ', len(X_test))
# Out:
# Train Size   :  160
# Val Size     :  29
# Test Size    :  22

# %%
import matplotlib
print(matplotlib.rcParams['image.cmap'])
# Out:
# viridis

# %%
img = Image.open(IMAGE_PATH + '/' + df['id'][100] + '.png')
mask = Image.open(MASK_PATH + '/' + df['id'][100] + '.png')
print('Image Size', np.asarray(img).shape)
print('Mask Size', np.asarray(mask).shape)


plt.imshow(img, cmap = 'viridis')
msk = plt.imshow(mask, alpha=0.6, cmap ='viridis')
plt.title('Picture with Mask Appplied')
#plt.show()

# Add a colorbar to show the mapping between colors and data values
plt.colorbar(msk)

# Show the plot
plt.show()
# Out:
# Image Size (600, 1000, 3)
# Mask Size (600, 1000)

# %%
from torchvision import transforms as T

class CarDataset(Dataset):
    
    def __init__(self, img_path, mask_path, X, mean, std, transform=None):
        self.img_path = img_path
        self.mask_path = mask_path
        self.X = X
        self.transform = transform
        self.mean = mean
        self.std = std

    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        img = cv2.imread(self.img_path + self.X[idx] + '.png')
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.mask_path + self.X[idx] + '.png', cv2.IMREAD_GRAYSCALE)
        
        if self.transform is not None:
            aug = self.transform(image=img, mask=mask)
            img = Image.fromarray(aug['image'])
            mask = aug['mask']
        
        if self.transform is None:
            img = Image.fromarray(img)
        
        t = T.Compose([T.ToTensor(), T.Normalize(self.mean, self.std)])
        img = t(img)
        mask = torch.from_numpy(mask).long()
            
        return img, mask

# %%
mean=[0.485, 0.456, 0.406]
std=[0.229, 0.224, 0.225]

t_train = A.Compose([A.Resize(256, 256, interpolation=cv2.INTER_NEAREST), A.HorizontalFlip(), A.VerticalFlip(),
                     A.GaussNoise()])

t_val = A.Compose([A.Resize(256, 256, interpolation=cv2.INTER_NEAREST)])

#datasets
train_set = CarDataset(IMAGE_PATH, MASK_PATH, X_train, mean, std, t_train)
val_set = CarDataset(IMAGE_PATH, MASK_PATH, X_val, mean, std, t_val)

#dataloader
batch_size= 8 

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=True)

# %% [markdown]
# # Models

# %% [markdown]
# # Segnet

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import torch.nn.functional as F


class SegNet(nn.Module):

    def __init__(self, in_chn=3, out_chn=32, BN_momentum=0.5):
        super(SegNet, self).__init__()

        #SegNet Architecture
        #Takes input of size in_chn = 3 (RGB images have 3 channels)
        #Outputs size label_chn (N # of classes)

        #ENCODING consists of 5 stages
        #Stage 1, 2 has 2 layers of Convolution + Batch Normalization + Max Pool respectively
        #Stage 3, 4, 5 has 3 layers of Convolution + Batch Normalization + Max Pool respectively

        #General Max Pool 2D for ENCODING layers
        #Pooling indices are stored for Upsampling in DECODING layers

        self.in_chn = in_chn
        self.out_chn = out_chn

        self.MaxEn = nn.MaxPool2d(2, stride=2, return_indices=True) 

        self.ConvEn11 = nn.Conv2d(self.in_chn, 64, kernel_size=3, padding=1)
        self.BNEn11 = nn.BatchNorm2d(64, momentum=BN_momentum)
        self.ConvEn12 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.BNEn12 = nn.BatchNorm2d(64, momentum=BN_momentum)

        self.ConvEn21 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.BNEn21 = nn.BatchNorm2d(128, momentum=BN_momentum)
        self.ConvEn22 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.BNEn22 = nn.BatchNorm2d(128, momentum=BN_momentum)

        self.ConvEn31 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.BNEn31 = nn.BatchNorm2d(256, momentum=BN_momentum)
        self.ConvEn32 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.BNEn32 = nn.BatchNorm2d(256, momentum=BN_momentum)
        self.ConvEn33 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.BNEn33 = nn.BatchNorm2d(256, momentum=BN_momentum)

        self.ConvEn41 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.BNEn41 = nn.BatchNorm2d(512, momentum=BN_momentum)
        self.ConvEn42 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.BNEn42 = nn.BatchNorm2d(512, momentum=BN_momentum)
        self.ConvEn43 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.BNEn43 = nn.BatchNorm2d(512, momentum=BN_momentum)

        self.ConvEn51 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.BNEn51 = nn.BatchNorm2d(512, momentum=BN_momentum)
        self.ConvEn52 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.BNEn52 = nn.BatchNorm2d(512, momentum=BN_momentum)
        self.ConvEn53 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.BNEn53 = nn.BatchNorm2d(512, momentum=BN_momentum)


        #DECODING consists of 5 stages
        #Each stage corresponds to their respective counterparts in ENCODING

        #General Max Pool 2D/Upsampling for DECODING layers
        self.MaxDe = nn.MaxUnpool2d(2, stride=2) 

        self.ConvDe53 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.BNDe53 = nn.BatchNorm2d(512, momentum=BN_momentum)
        self.ConvDe52 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.BNDe52 = nn.BatchNorm2d(512, momentum=BN_momentum)
        self.ConvDe51 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.BNDe51 = nn.BatchNorm2d(512, momentum=BN_momentum)

        self.ConvDe43 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.BNDe43 = nn.BatchNorm2d(512, momentum=BN_momentum)
        self.ConvDe42 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.BNDe42 = nn.BatchNorm2d(512, momentum=BN_momentum)
        self.ConvDe41 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.BNDe41 = nn.BatchNorm2d(256, momentum=BN_momentum)

        self.ConvDe33 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.BNDe33 = nn.BatchNorm2d(256, momentum=BN_momentum)
        self.ConvDe32 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.BNDe32 = nn.BatchNorm2d(256, momentum=BN_momentum)
        self.ConvDe31 = nn.Conv2d(256, 128, kernel_size=3, padding=1)
        self.BNDe31 = nn.BatchNorm2d(128, momentum=BN_momentum)

        self.ConvDe22 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.BNDe22 = nn.BatchNorm2d(128, momentum=BN_momentum)
        self.ConvDe21 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
        self.BNDe21 = nn.BatchNorm2d(64, momentum=BN_momentum)

        self.ConvDe12 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.BNDe12 = nn.BatchNorm2d(64, momentum=BN_momentum)
        self.ConvDe11 = nn.Conv2d(64, self.out_chn, kernel_size=3, padding=1)
        self.BNDe11 = nn.BatchNorm2d(self.out_chn, momentum=BN_momentum)

    def forward(self, x):

        #ENCODE LAYERS
        #Stage 1
        x = F.relu(self.BNEn11(self.ConvEn11(x))) 
        x = F.relu(self.BNEn12(self.ConvEn12(x))) 
        x, ind1 = self.MaxEn(x)
        size1 = x.size()

        #Stage 2
        x = F.relu(self.BNEn21(self.ConvEn21(x))) 
        x = F.relu(self.BNEn22(self.ConvEn22(x))) 
        x, ind2 = self.MaxEn(x)
        size2 = x.size()

        #Stage 3
        x = F.relu(self.BNEn31(self.ConvEn31(x))) 
        x = F.relu(self.BNEn32(self.ConvEn32(x))) 
        x = F.relu(self.BNEn33(self.ConvEn33(x)))   
        x, ind3 = self.MaxEn(x)
        size3 = x.size()

        #Stage 4
        x = F.relu(self.BNEn41(self.ConvEn41(x))) 
        x = F.relu(self.BNEn42(self.ConvEn42(x))) 
        x = F.relu(self.BNEn43(self.ConvEn43(x)))   
        x, ind4 = self.MaxEn(x)
        size4 = x.size()

        #Stage 5
        x = F.relu(self.BNEn51(self.ConvEn51(x))) 
        x = F.relu(self.BNEn52(self.ConvEn52(x))) 
        x = F.relu(self.BNEn53(self.ConvEn53(x)))   
        x, ind5 = self.MaxEn(x)
        size5 = x.size()

        #DECODE LAYERS
        #Stage 5
        x = self.MaxDe(x, ind5, output_size=size4)
        x = F.relu(self.BNDe53(self.ConvDe53(x)))
        x = F.relu(self.BNDe52(self.ConvDe52(x)))
        x = F.relu(self.BNDe51(self.ConvDe51(x)))

        #Stage 4
        x = self.MaxDe(x, ind4, output_size=size3)
        x = F.relu(self.BNDe43(self.ConvDe43(x)))
        x = F.relu(self.BNDe42(self.ConvDe42(x)))
        x = F.relu(self.BNDe41(self.ConvDe41(x)))

        #Stage 3
        x = self.MaxDe(x, ind3, output_size=size2)
        x = F.relu(self.BNDe33(self.ConvDe33(x)))
        x = F.relu(self.BNDe32(self.ConvDe32(x)))
        x = F.relu(self.BNDe31(self.ConvDe31(x)))

        #Stage 2
        x = self.MaxDe(x, ind2, output_size=size1)
        x = F.relu(self.BNDe22(self.ConvDe22(x)))
        x = F.relu(self.BNDe21(self.ConvDe21(x)))

        #Stage 1
        x = self.MaxDe(x, ind1)
        x = F.relu(self.BNDe12(self.ConvDe12(x)))
        x = self.ConvDe11(x)

        x = F.softmax(x, dim=1)

        return x


model = SegNet(3,5)

# https://github.com/vinceecws/SegNet_PyTorch

# %% [markdown]
# ## UNet

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class DoubleConv(nn.Module):
    """(convolution => [BN] => ReLU) * 2"""

    def __init__(self, in_channels, out_channels, mid_channels=None):
        super().__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)


class Down(nn.Module):
    """Downscaling with maxpool then double conv"""

    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_channels, out_channels)
        )

    def forward(self, x):
        return self.maxpool_conv(x)


class Up(nn.Module):
    """Upscaling then double conv"""

    def __init__(self, in_channels, out_channels):
        super().__init__()

        self.up = nn.ConvTranspose2d(in_channels, in_channels // 2, kernel_size=2, stride=2)
        self.conv = DoubleConv(in_channels, out_channels)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        # input is CHW
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]

        x1 = F.pad(x1, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        # if you have padding issues, see
        # https://github.com/HaiyongJiang/U-Net-Pytorch-Unstructured-Buggy/commit/0e854509c2cea854e247a9c615f175f76fbb2e3a
        # https://github.com/xiaopeng-liao/Pytorch-UNet/commit/8ebac70e633bac59fc22bb5195e513d5832fb3bd
        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)


class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        return self.conv(x)

# %%
""" Full assembly of the parts to form the complete network """
class UNet(nn.Module):
    def __init__(self, n_channels, n_classes):
        super(UNet, self).__init__()
        self.n_channels = n_channels
        self.n_classes = n_classes

        self.inc = (DoubleConv(n_channels, 64))
        self.down1 = (Down(64, 128))
        self.down2 = (Down(128, 256))
        self.down3 = (Down(256, 512))
        self.down4 = (Down(512, 1024))
        self.up1 = (Up(1024, 512))
        self.up2 = (Up(512, 256))
        self.up3 = (Up(256, 128))
        self.up4 = (Up(128, 64))
        self.outc = (OutConv(64, n_classes))

    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x = self.up1(x5, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)
        logits = self.outc(x)
        return logits

model = UNet(3, 5)

# https://github.com/milesial/Pytorch-UNet

# %% [markdown]
# ## Pretrained Segmentation Models Pytorch
# ## UNet with MobileNet Encoder
#
# https://github.com/qubvel/segmentation_models.pytorch

# %%
# !pip install -q segmentation-models-pytorch
import segmentation_models_pytorch as smp


model = smp.Unet('mobilenet_v2', encoder_weights='imagenet', classes=5, activation=None, encoder_depth=5, decoder_channels=[256, 128, 64, 32, 16])
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 KB 9.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 KB 42.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 17.2 MB/s eta 0:00:00
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Building wheel for pretrainedmodels (setup.py) ... done
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 93.7MB/s]

# %%
# Calculate pixel accuracy over a batch of images
def pixel_accuracy(output, mask):
    with torch.no_grad():
        output = torch.argmax(F.softmax(output, dim=1), dim=1)
        correct = torch.eq(output, mask).int()
        accuracy = float(correct.sum()) / float(correct.numel())
    return accuracy

# %%
# Calculate mean Intersection-over-Union over a batch of images
def mIoU(pred_mask, mask, smooth=1e-10, n_classes=5):
    with torch.no_grad():
        pred_mask = F.softmax(pred_mask, dim=1)
        pred_mask = torch.argmax(pred_mask, dim=1)
        pred_mask = pred_mask.contiguous().view(-1)
        mask = mask.contiguous().view(-1)

        iou_per_class = []
        for clas in range(0, n_classes): #loop per pixel class
            true_class = pred_mask == clas
            true_label = mask == clas

            if true_label.long().sum().item() == 0: #no exist label in this loop
                iou_per_class.append(np.nan)
            else:
                intersect = torch.logical_and(true_class, true_label).sum().float().item()
                union = torch.logical_or(true_class, true_label).sum().float().item()

                iou = (intersect + smooth) / (union +smooth)
                iou_per_class.append(iou)
        return np.nanmean(iou_per_class)

# %%
# Inner loop for running the model for 1 epoch over a given loader

def run_1_epoch(model, loss_fn, loader, optimizer = None, train = False):
  
  if train:
    model.train()
  else:
    model.eval()


  total_correct_preds = 0
  
  total_loss = 0

  # Number of images we can get by the loader
  total_samples_in_loader = len(loader.dataset)
  
  # number of batches we can get by the loader 
  total_batches_in_loader = len(loader)

  for image_batch, labels in tqdm(loader):
    
    # Transfer image_batch to GPU if available
    image_batch = image_batch.to(device)
    labels = labels.to(device)
    
    # Zeroing out the gradients for parameters
    if train:
      assert optimizer is not None, "Optimizer must be provided if train=True"
      optimizer.zero_grad()
    
    # Forward pass on the input batch
    output = model(image_batch)

    # Acquire predicted class indices
    _, predicted = torch.max(output.data, 1) # the dimension 1 corresponds to max along the rows 
    
    # Removing extra last dimension from output tensor
    #output.squeeze_(-1)

    # Compute the loss for the minibatch
    loss = loss_function(output, labels)
    
    # Backpropagation
    if train:
      loss.backward()
    
    # Update the parameters using the gradients
    if train:
      optimizer.step()
    
    # Extra variables for calculating loss and accuracy
    # count total predictions for accuracy calcutuon for this epoch
    #total_correct_preds += (predicted == labels).sum().item()

    total_loss += loss.item()

  loss = total_loss / total_batches_in_loader
  accuracy = pixel_accuracy(output, labels)
  mean_IoU = mIoU(output, labels)

  return loss, accuracy, mean_IoU

# %% [markdown]
# ### Training Configuration

# %%
# Select a loss function
loss_function = torch.nn.CrossEntropyLoss()

# Select an optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Define the learning rate scheduler
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=40, gamma=0.1)
# For more on schedulers please visit:
# https://towardsdatascience.com/a-visual-guide-to-learning-rate-schedulers-in-pytorch-24bbb262c863

# Set the number of epochs
# This variable is used in the main training loop
epochs = 10

model.to(device);

# %%
# Initializing variables for starting a new training
# Some helper variables

train_accuracies = []
val_accuracies = []

train_losses = []
val_losses = []

train_mIoUs = []
val_mIoUs = []

val_mIoU_max = -1

checkpoint_path = '/content/checkpoint_norm_aug_tensorboard.pth'
best_val_checkpoint_path = '/content/best_val_checkpoint_norm_aug_tensorboard.pth'

# Start epoch is zero for new training
start_epoch = 0

# %% [markdown]
# ### Main training loop

# %%
# Main training and validation loop for n number of epochs
for epoch in range(start_epoch, epochs):

  # Train model for one epoch

  # Get the current learning rate from the optimizer
  current_lr = optimizer.param_groups[0]['lr']

  print("Epoch %d: Train \nLearning Rate: %.6f"%(epoch, current_lr))
  train_loss, train_accuracy, train_mIoU  = run_1_epoch(model, loss_function, train_loader, optimizer, train= True)

  # Update the learning rate scheduler
  scheduler.step()

  # Lists for train loss and accuracy for plotting
  train_losses.append(train_loss)
  train_accuracies.append(train_accuracy)
  train_mIoUs.append(train_mIoU)

  # Validate the model on validation set
  print("Epoch %d: Validation"%(epoch))
  with torch.no_grad():
    val_loss, val_accuracy, val_mIoU  = run_1_epoch(model, loss_function, val_loader, optimizer, train= False)
  
  # Lists for val loss and accuracy for plotting
  val_losses.append(val_loss)
  val_accuracies.append(val_accuracy)
  val_mIoUs.append(val_mIoU)

  # The "add_scalar" function adds a new metric to the tensorboard log
  # It is gnerally given 3 arguments:
  # tag: Name of the metric
  # scalar_value = the value of the metric to record
  # global_step = on which milestone to record the scalar value which in our
  # case is the epoch
  # writer.add_scalar(tag = "Loss/train", scalar_value = train_loss, global_step = epoch)
  # writer.add_scalar(tag = "accuracy/train", scalar_value = train_accuracy, global_step = epoch)

  # writer.add_scalar(tag = "Loss/val", scalar_value = val_loss, global_step = epoch)
  # writer.add_scalar(tag = "accuracy/val", scalar_value = val_accuracy, global_step = epoch)

  print('train loss: %.4f'%(train_loss))
  print('val loss: %.4f'%(val_loss))
  print('train_accuracy %.2f' % (train_accuracy))
  print('val_accuracy %.2f' % (val_accuracy))
  print('train_IoU %.2f'%(train_mIoU))
  print('val_IoU %.2f'%(val_mIoU))
  
  # Save model if validation accuracy for current epoch is greater than 
  # all the previous epochs 
  if val_mIoU > val_mIoU_max:
    val_mIoU_max = val_mIoU
    print("New max val mean IoU Acheived %.2f. Saving model.\n\n"%(val_mIoU_max))

    checkpoint = {
    'model': model.state_dict(),
    'optimizer': optimizer.state_dict(),
    'scheduler': scheduler.state_dict(),
    'trianed_epochs': epoch,
    'train_losses': train_losses,
    'train_accuracies': train_accuracies,
    'train_mIoUs': train_mIoUs,
    'val_losses': val_losses,
    'val_accuracies': val_accuracies,
    'val_accuracy_max': val_mIoU_max,
    'val_mIoUs': val_mIoUs,
    'lr': optimizer.param_groups[0]['lr']
    }
    torch.save(checkpoint, best_val_checkpoint_path)

  else:
    print("val mean IoU did not increase from %.2f\n\n"%(val_mIoU_max))

# Save checkpoint for the last epoch
  checkpoint = {
    'model': model.state_dict(),
    'optimizer': optimizer.state_dict(),
    'scheduler': scheduler.state_dict(),
    'trianed_epochs': epoch,
    'train_losses': train_losses,
    'train_accuracies': train_accuracies,
    'train_mIoUs': train_mIoUs,
    'val_losses': val_losses,
    'val_accuracies': val_accuracies,
    'val_accuracy_max': val_mIoU_max,
    'val_mIoUs': val_mIoUs,
    'lr': optimizer.param_groups[0]['lr']
    }

  torch.save(checkpoint, checkpoint_path)
# Out:
# Epoch 0: Train
# Learning Rate: 0.001000
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 0: Validation
#   0%|          | 0/4 [00:00<?, ?it/s]
# train loss: 0.9400
# val loss: 1.5973
# train_accuracy 0.89
# val_accuracy 0.82
# train_IoU 0.49
# val_IoU 0.37
# New max val mean IoU Acheived 0.37. Saving model.
#
#
# Epoch 1: Train
# Learning Rate: 0.001000
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 1: Validation
#   0%|          | 0/4 [00:00<?, ?it/s]
# train loss: 0.3471
# val loss: 0.3049
# train_accuracy 0.90
# val_accuracy 0.92
# train_IoU 0.52
# val_IoU 0.54
# New max val mean IoU Acheived 0.54. Saving model.
#
#
# Epoch 2: Train
# Learning Rate: 0.001000
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 2: Validation
#   0%|          | 0/4 [00:00<?, ?it/s]
# train loss: 0.2566
# val loss: 0.2721
# train_accuracy 0.91
# val_accuracy 0.90
# train_IoU 0.60
# val_IoU 0.52
# val mean IoU did not increase from 0.54
#
#
# Epoch 3: Train
# Learning Rate: 0.001000
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 3: Validation
#   0%|          | 0/4 [00:00<?, ?it/s]
# train loss: 0.1904
# val loss: 0.2028
# train_accuracy 0.94
# val_accuracy 0.93
# train_IoU 0.63
# val_IoU 0.59
# New max val mean IoU Acheived 0.59. Saving model.
#
#
# Epoch 4: Train
# Learning Rate: 0.001000
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 4: Validation
#   0%|          | 0/4 [00:00<?, ?it/s]
# train loss: 0.1601
# val loss: 0.1614
# train_accuracy 0.94
# val_accuracy 0.96
# train_IoU 0.62
# val_IoU 0.67
# New max val mean IoU Acheived 0.67. Saving model.
#
#
# Epoch 5: Train
# Learning Rate: 0.001000
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 5: Validation
#   0%|          | 0/4 [00:00<?, ?it/s]
# train loss: 0.1575
# val loss: 0.1539
# train_accuracy 0.95
# val_accuracy 0.95
# train_IoU 0.68
# val_IoU 0.68
# New max val mean IoU Acheived 0.68. Saving model.
#
#
# Epoch 6: Train
# Learning Rate: 0.001000
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 6: Validation
#   0%|          | 0/4 [00:00<?, ?it/s]
# train loss: 0.1701
# val loss: 0.1963
# train_accuracy 0.96
# val_accuracy 0.95
# train_IoU 0.69
# val_IoU 0.65
# val mean IoU did not increase from 0.68
#
#
# Epoch 7: Train
# Learning Rate: 0.001000
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 7: Validation
#   0%|          | 0/4 [00:00<?, ?it/s]
# train loss: 0.1627
# val loss: 0.2022
# train_accuracy 0.90
# val_accuracy 0.94
# train_IoU 0.62
# val_IoU 0.65
# val mean IoU did not increase from 0.68
#
#
# Epoch 8: Train
# Learning Rate: 0.001000
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 8: Validation
#   0%|          | 0/4 [00:00<?, ?it/s]
# train loss: 0.1508
# val loss: 0.1771
# train_accuracy 0.96
# val_accuracy 0.93
# train_IoU 0.68
# val_IoU 0.64
# val mean IoU did not increase from 0.68
#
#
# Epoch 9: Train
# Learning Rate: 0.001000
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 9: Validation
#   0%|          | 0/4 [00:00<?, ?it/s]
# train loss: 0.1425
# val loss: 0.1419
# train_accuracy 0.92
# val_accuracy 0.97
# train_IoU 0.62
# val_IoU 0.70
# New max val mean IoU Acheived 0.70. Saving model.

# %%
plt.figure()
plt.plot(train_accuracies, label="train_accuracy")
plt.plot(val_accuracies, label="val_accuracy")
plt.legend()

plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.title('Training and val Accuracy')

plt.figure()
plt.plot(train_losses, label="train_loss")
plt.plot(val_losses, label="val_loss")

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and val Loss')

plt.figure()
plt.plot(train_mIoUs, label="train_mIoU")
plt.plot(val_mIoUs, label="val_mIoU")

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('mIoU')
plt.title('Training and val mIoU')
# Out:
# Text(0.5, 1.0, 'Training and val mIoU')

# %% [markdown]
# # Evaluation

# %%
# !gdown https://drive.google.com/file/d/1-I2Up6QlCZrw0M_9BjwbEkE_TW5QnHJL/view?usp=share_link --fuzzy
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-I2Up6QlCZrw0M_9BjwbEkE_TW5QnHJL
# To: /content/best_cars_checkpoint.pth
# 100% 80.0M/80.0M [00:05<00:00, 13.8MB/s]

# %%
best_val_model_path = '/content/best_cars_checkpoint.pth'
best_val_checkpoint = torch.load(best_val_model_path, map_location=torch.device(device))
# Before loading the state_dict of the model, make sure the "model" instance is 
# initiated by its corresponding class e.g. VGG16
model.load_state_dict(best_val_checkpoint['model'])
# Out:
# <All keys matched successfully>

# %%
class DroneTestDataset(Dataset):
    
    def __init__(self, img_path, mask_path, X, transform=None):
        self.img_path = img_path
        self.mask_path = mask_path
        self.X = X
        self.transform = transform
      
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        img = cv2.imread(self.img_path + self.X[idx] + '.png')
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.mask_path + self.X[idx] + '.png', cv2.IMREAD_GRAYSCALE)
        
        if self.transform is not None:
            aug = self.transform(image=img, mask=mask)
            img = Image.fromarray(aug['image'])
            mask = aug['mask']
        
        if self.transform is None:
            img = Image.fromarray(img)
        
        mask = torch.from_numpy(mask).long()
        
        return img, mask


t_test = A.Resize(256, 256, interpolation=cv2.INTER_NEAREST)
test_set = DroneTestDataset(IMAGE_PATH, MASK_PATH, X_test, transform=t_test)

# %%
def predict_image_mask_miou(model, image, mask, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]):
    model.eval()
    t = T.Compose([T.ToTensor(), T.Normalize(mean, std)])
    image = t(image)
    model.to(device); image=image.to(device)
    mask = mask.to(device)
    with torch.no_grad():
        
        image = image.unsqueeze(0)
        mask = mask.unsqueeze(0)
        
        output = model(image)
        score = mIoU(output, mask)
        masked = torch.argmax(output, dim=1)
        masked = masked.cpu().squeeze(0)
    return masked, score

# %%
def test_miou_score(model, test_set):
    score_iou = []
    for i in tqdm(range(len(test_set))):
        img, mask = test_set[i]
        pred_mask, score = predict_image_mask_miou(model, img, mask)
        score_iou.append(score)
    return score_iou

# %%
mob_miou = test_miou_score(model, test_set)
np.mean(mob_miou)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 0.6635504172334894

# %%
def display_for_comparison(image, mask, pred_mask):

  fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(20,10))
  ax1.imshow(image)
  ax1.set_title('Picture');

  ax2.imshow(mask)
  ax2.set_title('Ground truth')
  ax2.set_axis_off()

  ax3.imshow(pred_mask)
  ax3.set_title('UNet-MobileNet | mIoU {:.3f}'.format(score))
  ax3.set_axis_off()

# %%
image, mask = test_set[3]
pred_mask, score = predict_image_mask_miou(model, image, mask)

display_for_comparison(image, mask, pred_mask)

# %%
image2, mask2 = test_set[9]
pred_mask2, score2 = predict_image_mask_miou(model, image2, mask2)


display_for_comparison(image2, mask2, pred_mask2)

# %%
image3, mask3 = test_set[15]
pred_mask3, score3 = predict_image_mask_miou(model, image3, mask3)


display_for_comparison(image3, mask3, pred_mask3)

# %% [markdown]
# # Credits
# - Notebook Prepared by Bostan Khan, Team Lead, MachVIS Lab
#
# - https://www.kaggle.com/code/ligtfeather/semantic-segmentation-is-easy-with-pytorch
